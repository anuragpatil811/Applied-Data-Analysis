# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(data=df, hue="species")

# %%
df[["petal_length", "petal_width"]].corr()
# Out:
#               petal_length  petal_width
# petal_length      1.000000     0.962865
# petal_width       0.962865     1.000000

# %%
sns.heatmap(df[["petal_length", "petal_width"]].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.violinplot(x="species", y="petal_length", data=df)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(x="species", y="sepal_width", data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.boxplot(data=df, x="species", y="petal_length")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
df["petal_length"].describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
q1 = 1.60 
q1
# Out:
# 1.6

# %%
q3 = 5.1
q3
# Out:
# 5.1

# %%
IQR = q3 - q1 
IQR
# Out:
# 3.4999999999999996

# %%
upper_bound  = q3 + 1.5*IQR 
upper_bound
# Out:
# 10.349999999999998

# %%
lower_bound = q1 - 1.5 * IQR 
lower_bound
# Out:
# -3.649999999999999

# %%
df1 = df[(df["petal_length"]< upper_bound)&(df["petal_length"]>lower_bound)]

# %%
sns.boxplot(x="species", y="petal_length", data=df1)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x="species", y="sepal_length", data=df1)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df2 = df1[df1["species"]=="virginica"]
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
q1 = 6.2

# %%
q3 =  6.9
q3
# Out:
# 6.9

# %%
IQR = q3 - q1 
IQR
# Out:
# 0.7000000000000002

# %%
u_f = q3 + 1.5*IQR
u_f
# Out:
# 7.950000000000001

# %%
l_f = q1 - 1.5*IQR 
l_f
# Out:
# 5.15

# %%
df2 = df2[(df2["sepal_length"]<q3)&(df2["sepal_length"]>q1)]
sns.boxplot(x="species", y="sepal_length", data=df2)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
#Petal Length 
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     22.000000    22.000000     22.000000    22.000000
# mean       6.495455     2.990909      5.477273     2.077273
# std        0.178558     0.256179      0.300685     0.270681
# min        6.300000     2.500000      4.900000     1.500000
# 25%        6.325000     2.800000      5.225000     1.825000
# 50%        6.450000     3.000000      5.550000     2.100000
# 75%        6.700000     3.200000      5.675000     2.300000
# max        6.800000     3.400000      6.000000     2.500000

# %%
Q1 = 5.2
Q1
# Out:
# 5.2

# %%
Q3 = 5.6
Q3
# Out:
# 5.6

# %%
IQR = Q3 - Q1 
IQR
# Out:
# 0.39999999999999947

# %%
upper = Q3 + 1.5*IQR
upper
# Out:
# 6.199999999999999

# %%
lower = Q1 - 1.5*IQR 
lower
# Out:
# 4.600000000000001

# %%
df2 = df2[(df2["petal_length"]<upper)&(df2["petal_length"]>lower)]

# %%
sns.boxplot(x="species", y="petal_length", data=df2)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18, 18))
plt.subplot(5, 2, 1)
sns.boxplot(data=df1, x="species", y="petal_width")

plt.subplot(5, 2, 2)
sns.boxplot(data=df1, x="species", y="petal_length")
plt.show()

# %%
plt.subplot(3, 3, 1)
plt.subplot(3, 3, 2)
plt.subplot(3, 3, 3)
plt.subplot(3, 3, 4)
plt.subplot(3, 3, 5)
plt.subplot(3, 3, 6)
plt.subplot(3, 3, 7)
plt.subplot(3, 3, 8)
plt.subplot(3, 3, 9)
# Out:
# <Axes: >

# %%
import plotly.express as ex

# %%
ex.box(data_frame=df, y="petal_width")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...
