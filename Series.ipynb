# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragpatil811/Applied-Data-Analysis/blob/main/Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
marks = pd.Series([85, 90, 91, 100], index=['Anurag', 'Ritesh', 'Anil', 'Aayush'])

# %%
marks
# Out:
# Anurag     85
# Ritesh     90
# Anil       91
# Aayush    100
# dtype: int64

# %%
marks['Ritesh']
# Out:
# np.int64(90)
