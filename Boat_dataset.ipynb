# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\Python\Pandas\Boat_dataSet.csv")

# %%
df.head()
# Out:
#      Price     Boat Type Manufacturer  Type  Year Built  Length  Width  \
# 0  3311095      Sailboat      Sea Ray   New        2004   11.35   5.49
# 1  3611781      Sailboat       Yamaha   New        2024   29.72   4.89
# 2  4174877      Sailboat     Jeanneau  Used        1990   15.22   9.58
# 3  3940148  Fishing Boat       Yamaha   New        2019   32.44   4.37
# 4    88418     Motorboat     Bayliner   New        1996   32.21   4.35
#
#    Material       Location  Number of views last 7 days   Prices
# 0     Steel        Chennai                           17   459146
# 1     Steel          Kochi                          150   877609
# 2  Aluminum  Visakhapatnam                          435  3903807
# 3     Steel          Kochi                          201   460983
# 4     Steel          Kochi                          229  3528377

# %%
df.drop("Prices", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        2000 non-null   int64
#  1   Boat Type                    2000 non-null   object
#  2   Manufacturer                 2000 non-null   object
#  3   Type                         2000 non-null   object
#  4   Year Built                   2000 non-null   int64
#  5   Length                       2000 non-null   float64
#  6   Width                        2000 non-null   float64
#  7   Material                     2000 non-null   object
#  8   Location                     2000 non-null   object
#  9   Number of views last 7 days  2000 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 156.4+ KB

# %%
df.isnull().sum()
# Out:
# Price                          0
# Boat Type                      0
# Manufacturer                   0
# Type                           0
# Year Built                     0
# Length                         0
# Width                          0
# Material                       0
# Location                       0
# Number of views last 7 days    0
# dtype: int64

# %%
df["Length"] = df["Length"].astype(int)

# %%
df["Width"] = df["Width"].astype(int)

# %%
df["Boat Type"].unique()
# Out:
# array(['Sailboat', 'Fishing Boat', 'Motorboat', 'Jet Ski', 'Yacht'],
#       dtype=object)

# %%
df.groupby("Boat Type")["Price"].mean()
# Out:
# Boat Type
# Fishing Boat    2.575438e+06
# Jet Ski         2.510432e+06
# Motorboat       2.494246e+06
# Sailboat        2.642401e+06
# Yacht           2.560342e+06
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.bar(df["Boat Type"].unique(), df.groupby("Boat Type")["Price"].mean())
plt.xlabel("Boat Type")
plt.ylabel("Average Price")
plt.title("Average Price by Boat Type")
plt.show()

# %%
df["Manufacturer"].unique()
# Out:
# array(['Sea Ray', 'Yamaha', 'Jeanneau', 'Bayliner', 'Boston Whaler',
#        'Beneteau'], dtype=object)

# %%
df.groupby("Manufacturer")["Price"].mean()
# Out:
# Manufacturer
# Bayliner         2.569102e+06
# Beneteau         2.556617e+06
# Boston Whaler    2.560260e+06
# Jeanneau         2.598940e+06
# Sea Ray          2.494748e+06
# Yamaha           2.561740e+06
# Name: Price, dtype: float64

# %%
plt.bar(df["Manufacturer"].unique(), df.groupby("Manufacturer")["Price"].mean())
# Out:
# <BarContainer object of 6 artists>

# %%
df2 = df[df["Year Built"] > 2010]

# %%
df2["Year Built"].unique()
# Out:
# array([2024, 2019, 2018, 2021, 2016, 2020, 2013, 2012, 2014, 2017, 2015,
#        2011, 2023, 2022])

# %%
df2.groupby("Year Built")["Price"].mean()
# Out:
# Year Built
# 2011    2.552443e+06
# 2012    2.910181e+06
# 2013    2.494580e+06
# 2014    2.632320e+06
# 2015    2.403866e+06
# 2016    2.817379e+06
# 2017    2.471850e+06
# 2018    2.203445e+06
# 2019    2.804994e+06
# 2020    2.695542e+06
# 2021    2.426472e+06
# 2022    2.774371e+06
# 2023    2.796454e+06
# 2024    2.856076e+06
# Name: Price, dtype: float64

# %%
plt.bar(df2["Year Built"].unique(), df2.groupby("Year Built")["Price"].mean())
# Out:
# <BarContainer object of 14 artists>

# %%
df2["Location"].unique()
df2.groupby("Location")["Price"].mean()
# Out:
# Location
# Chennai          2712374
# Goa              2638535
# Kochi            2530027
# Mumbai           2643887
# Visakhapatnam    2585774
# Name: Price, dtype: int64

# %%
plt.bar(df2["Location"].unique(), df2.groupby("Location")["Price"].mean())
plt.xlabel("Location")
plt.ylabel("Average Price")
plt.title("Average Price by Location for Boats Built After 2010")
# Out:
# Text(0.5, 1.0, 'Average Price by Location for Boats Built After 2010')

# %%
df2["Location"].unique()
# Out:
# array(['Kochi', 'Visakhapatnam', 'Goa', 'Chennai', 'Mumbai'], dtype=object)

# %%
df2.columns
# Out:
# Index(['Price', 'Boat Type', 'Manufacturer', 'Type', 'Year Built', 'Length',
#        'Width', 'Material', 'Location', 'Number of views last 7 days'],
#       dtype='object')

# %%
df.groupby("Location")["Number of views last 7 days"].max()
# Out:
# Location
# Chennai          498
# Goa              497
# Kochi            499
# Mumbai           499
# Visakhapatnam    499
# Name: Number of views last 7 days, dtype: int64

# %%
plt.bar(df2["Location"].unique(), df.groupby("Location")["Number of views last 7 days"].max())
# Out:
# <BarContainer object of 5 artists>

# %%
#Relationship between price and length
plt.scatter(df2["Length"].unique(), df2.groupby("Length")["Price"].mean())

# %%
df1 = df.loc[0:20]

# %%
x = df1["Material"].value_counts()
x
# Out:
# Material
# Steel         8
# Aluminum      5
# Wood          5
# Fiberglass    3
# Name: count, dtype: int64

# %%
df1["Year Built"].unique()
# Out:
# array([2004, 2024, 1990, 2019, 1996, 2006, 2018, 1994, 2021, 2010, 1995,
#        2009, 2016, 2005, 2020, 2000])

# %%
df1.groupby("Year Built")["Material"].count()
# Out:
# Year Built
# 1990    2
# 1994    1
# 1995    1
# 1996    1
# 2000    1
# 2004    2
# 2005    1
# 2006    1
# 2009    3
# 2010    1
# 2016    1
# 2018    1
# 2019    2
# 2020    1
# 2021    1
# 2024    1
# Name: Material, dtype: int64

# %%
plt.bar(df1["Year Built"].unique(), df1.groupby("Year Built")["Material"].count())
# Out:
# <BarContainer object of 16 artists>

# %%
x = [10, 20, 30, 40]
y = [10, 20, 30, 90]

# %%
plt.plot(x, y)

# %%
ab = ["a", "b", "c", "d"]

# %%
plt.figure(figsize=(3, 2))
plt.fill_between(x, y)

# %%
plt.stackplot(ab, x, y)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        21 non-null     int64
#  1   Boat Type                    21 non-null     object
#  2   Manufacturer                 21 non-null     object
#  3   Type                         21 non-null     object
#  4   Year Built                   21 non-null     int64
#  5   Length                       21 non-null     int64
#  6   Width                        21 non-null     int64
#  7   Material                     21 non-null     object
#  8   Location                     21 non-null     object
#  9   Number of views last 7 days  21 non-null     int64
# dtypes: int64(5), object(5)
# memory usage: 1.8+ KB

# %%
totalpricebymaterial = df2.groupby("Material")["Price"].sum()

# %%
plt.pie(totalpricebymaterial, labels=df2["Material"].unique(), autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x24c96716010>,
# ...
#  [Text(0.7356137485310057, 0.8178462037401424, 'Steel'),
#   Text(-0.8482923381778195, 0.7002857338178524, 'Wood'),
#   Text(-0.7306765428999619, -0.8222601715124966, 'Aluminum'),
#   Text(0.7905492498550684, -0.7648737696859454, 'Fiberglass')],
#  [Text(0.40124386283509395, 0.4460979293128049, '26.7%'),
#   Text(-0.46270491173335604, 0.38197403662791946, '24.7%'),
#   Text(-0.3985508415817973, -0.4485055480977254, '24.2%'),
#   Text(0.43120868173912813, -0.417203874374152, '24.5%')])
