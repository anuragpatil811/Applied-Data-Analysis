# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragpatil811/Applied-Data-Analysis/blob/main/Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
products = ["Product A", "Product B", "Product C"]
sales = [5000, 7000, 6000]

# %%
plt.bar(products, sales, color=['blue', 'red', 'green'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel("Products", fontsize=12)
plt.ylabel("Sales", fontsize=12)
plt.title("Sales Comparision", fontsize=14, fontweight="bold")
plt.show()
