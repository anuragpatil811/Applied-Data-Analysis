# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\Python\Pandas\Military Expenditure.csv")

# %%
df.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08  3.258070e+08
# 2   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09  3.639496e+09
# 3   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08  1.970068e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#             Name Code     Type                      Indicator Name  \
# 11     Australia  AUS  Country  Military expenditure (current USD)
# 12       Austria  AUT  Country  Military expenditure (current USD)
# 15       Belgium  BEL  Country  Military expenditure (current USD)
# 17  Burkina Faso  BFA  Country  Military expenditure (current USD)
# 27        Brazil  BRA  Country  Military expenditure (current USD)
#
#             1960          1961          1962          1963          1964  \
# 11  4.597601e+08  4.709601e+08  4.894401e+08  5.532801e+08  6.557601e+08
# 12  9.155910e+07  9.102985e+07  1.000270e+08  1.259599e+08  1.645947e+08
# 15  3.832202e+08  3.912188e+08  4.222208e+08  4.446013e+08  4.970592e+08
# 17  1.268378e+06  1.643154e+06  4.901761e+06  5.281288e+06  5.358593e+06
# 27  3.827298e+08  3.423397e+08  3.874490e+08  4.419996e+08  3.542279e+08
#
#             1965  ...          2009          2010          2011          2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 66 entries, 11 to 261
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            66 non-null     str
#  1   Code            66 non-null     str
#  2   Type            66 non-null     str
#  3   Indicator Name  66 non-null     str
#  4   1960            66 non-null     float64
#  5   1961            66 non-null     float64
#  6   1962            66 non-null     float64
#  7   1963            66 non-null     float64
#  8   1964            66 non-null     float64
#  9   1965            66 non-null     float64
#  10  1966            66 non-null     float64
#  11  1967            66 non-null     float64
#  12  1968            66 non-null     float64
#  13  1969            66 non-null     float64
#  14  1970            66 non-null     float64
#  15  1971            66 non-null     float64
#  16  1972            66 non-null     float64
# ...

# %%
df2 = df[df["Year"] > 2000]
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ...
